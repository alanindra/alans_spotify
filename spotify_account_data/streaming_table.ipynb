# %% [markdown]
# JSON to table

# %%
import pandas as pd
from pathlib import Path
import os

folder = Path('/Users/qaulanmaruf/Desktop/alans_spotify_2025/spotify_account_data')

for file in folder.glob('StreamingHistory_music*'):
    print(file)
# Out:
# /Users/qaulanmaruf/Desktop/alans_spotify_2025/spotify_account_data/StreamingHistory_music_1.json
# /Users/qaulanmaruf/Desktop/alans_spotify_2025/spotify_account_data/StreamingHistory_music_0.json
# /Users/qaulanmaruf/Desktop/alans_spotify_2025/spotify_account_data/StreamingHistory_music_3.json
# /Users/qaulanmaruf/Desktop/alans_spotify_2025/spotify_account_data/StreamingHistory_music_2.json
